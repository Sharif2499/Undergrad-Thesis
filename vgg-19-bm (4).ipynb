# %%
from collections import Counter
import cv2
import os
import glob
import skimage
import numpy as np
import pandas as pd
import seaborn as sn
import preprocessing
from tqdm import tqdm
from PIL import Image
from os import listdir
import matplotlib.pyplot as plt
from skimage.transform import resize
from collections import Counter

sn.set()

from sklearn.svm import SVC # SVC
from sklearn import metrics
from sklearn.utils import shuffle
from xgboost import XGBClassifier # XGBClassifier
from sklearn import metrics
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils import compute_class_weight
from sklearn.preprocessing import MinMaxScaler,LabelBinarizer
from sklearn.ensemble import AdaBoostClassifier # AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier # KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier # RandomForestClassifier
from sklearn.model_selection import train_test_split

import tensorflow 
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.metrics import AUC
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.applications.vgg16 import VGG16 # VGG16
from tensorflow.keras.applications.vgg19 import VGG19 # VGG19
from tensorflow.keras.applications.resnet50 import ResNet50 # ResNet50
from tensorflow.keras.applications.xception import Xception # Xception
from tensorflow.keras.applications.mobilenet import MobileNet # MobileNet
from tensorflow.keras.applications.nasnet import NASNetMobile # NASNetMobile
from tensorflow.keras.applications.densenet import DenseNet169 # DenseNet169
from tensorflow.keras.applications.densenet import DenseNet121 # DenseNet121
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2 # MobileNetV2
from tensorflow.keras.applications.inception_v3 import InceptionV3 # InceptionV3
from tensorflow.keras.layers import Input, Dense, Dropout, BatchNormalization, Flatten, Activation, GlobalAveragePooling2D,Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
no_angles = 360
url ='/kaggle/input/mias-mammography/all-mias/'

# %%
def save_dictionary(path,data):
    print('saving catalog...')
    #open('u.item', encoding="utf-8")
    import json
    with open(path,'w') as outfile:
        json.dump(str(data), fp=outfile)
      # save to file:
    print(' catalog saved')

# %%
def read_image():
    print("Reading images")
    import cv2
    info = {}
    for i in range(322):
        if i<9:
            image_name='mdb00'+str(i+1)
        elif i<99:
            image_name='mdb0'+str(i+1)
        else:
            image_name = 'mdb' + str(i+1)
        # print(image_name)
        image_address= url+image_name+'.pgm'
        #print(image_address)
        #print(image_address)
        img = cv2.imread(image_address,1)
        # print(i)
        img = cv2.resize(img, (224,224))   #resize image
        rows, cols,color = img.shape
        info[image_name]={}
        for angle in range(0,no_angles,8):
            M = cv2.getRotationMatrix2D((cols / 2, rows / 2), angle, 1)    #Rotate 0 degree
            img_rotated = cv2.warpAffine(img, M, (cols, rows))
            info[image_name][angle]=img_rotated
    return (info)

# %%
def read_lable():
    print("Reading labels")
    filename = url+'Info.txt'
    text_all = open(filename).read()
    #print(text_all)
    lines=text_all.split('\n')
    info={}
    c=0
    d = 0
    for line in lines:
        words=line.split(' ')       
        if len(words)>3:
            if (words[3] == 'B'):
                
                info[words[0]] = {}
                for angle in range(0,no_angles,8):
                    info[words[0]][angle] = 0
                    c+=1
                
            
            
            if (words[3] == 'M'):
                
                info[words[0]] = {}
                for  angle in range(0,no_angles,8):
                    info[words[0]][angle] = 1
                    d+=1
    print(f'm: {d}')
    print(f'b: {c}')
    return (info)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
import numpy as np
lable_info=read_lable()
image_info=read_image()
#print(image_info[1][0])
ids=lable_info.keys()   #ids = acceptable labeled ids
#print(type(ids))
del lable_info['Truth-Data:']
#print(lable_info)
#print(ids)
X=[]
Y=[]
for id in ids:
    for angle in range(0,no_angles,8):
        X.append(image_info[id][angle])
        Y.append(lable_info[id][angle])
X=np.array(X)
Y=np.array(Y)
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.15, random_state=20,shuffle=True)
# cancer_prediction_cnn(x_train, y_train, x_test, y_test)
# Out:
# Reading labels
# m: 2475
# b: 3105
# Reading images

# %%
len(image_info), len(ids)
# Out:
# (322, 115)

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Conv2D, MaxPool2D, Flatten
from keras import optimizers
from keras import losses
from sklearn import metrics

rows, cols,color = x_train[0].shape
print(x_train[0].shape)

base_model = VGG19(input_shape=(224,224,3), weights='imagenet', include_top=False)
model=Sequential()
model.add(base_model)
model.add(Dropout(0.45))
model.add(Flatten())
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
#model.add(Dropout(0.2))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.45))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(1,activation='sigmoid'))

for layer in base_model.layers:
    layer.trainable = False

model.summary()
# Out:
# (224, 224, 3)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# vgg19 (Functional)           (None, 7, 7, 512)         20024384
# _________________________________________________________________
# dropout (Dropout)            (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# activation (Activation)      (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_1 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 1024)              4096
# _________________________________________________________________
# activation_2 (Activation)    (None, 1024)              0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 47,828,033
# Trainable params: 27,797,505
# Non-trainable params: 20,030,528
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', patience=6,restore_best_weights=True, verbose=1)

# %%
model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train,validation_split=0.2,shuffle=True, epochs=100, batch_size=32)
loss_value , accuracy = model.evaluate(x_test, y_test)

print('Test_loss_value = ' +str(loss_value))
print('test_accuracy = ' + str(accuracy))

#print(model.predict(x_test))
save_dictionary('history1.dat', history.history)
# Out:
# Epoch 1/100
# 110/110 [==============================] - 12s 106ms/step - loss: 0.7957 - accuracy: 0.6103 - val_loss: 0.7991 - val_accuracy: 0.7148
# Epoch 2/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.4022 - accuracy: 0.8235 - val_loss: 0.4587 - val_accuracy: 0.8295
# Epoch 3/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.2377 - accuracy: 0.8991 - val_loss: 0.1888 - val_accuracy: 0.9136
# Epoch 4/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.1755 - accuracy: 0.9306 - val_loss: 0.2306 - val_accuracy: 0.9125
# Epoch 5/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.1388 - accuracy: 0.9463 - val_loss: 0.1786 - val_accuracy: 0.9273
# Epoch 6/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.1061 - accuracy: 0.9628 - val_loss: 0.1163 - val_accuracy: 0.9511
# Epoch 7/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0958 - accuracy: 0.9642 - val_loss: 0.1324 - val_accuracy: 0.9455
# Epoch 8/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0962 - accuracy: 0.9656 - val_loss: 0.1109 - val_accuracy: 0.9557
# Epoch 9/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0670 - accuracy: 0.9784 - val_loss: 0.1151 - val_accuracy: 0.9614
# Epoch 10/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0816 - accuracy: 0.9704 - val_loss: 0.1098 - val_accuracy: 0.9625
# Epoch 11/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0678 - accuracy: 0.9756 - val_loss: 0.1033 - val_accuracy: 0.9580
# Epoch 12/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0615 - accuracy: 0.9798 - val_loss: 0.1277 - val_accuracy: 0.9511
# Epoch 13/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0698 - accuracy: 0.9756 - val_loss: 0.1268 - val_accuracy: 0.9511
# Epoch 14/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0548 - accuracy: 0.9784 - val_loss: 0.1172 - val_accuracy: 0.9602
# Epoch 15/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0554 - accuracy: 0.9804 - val_loss: 0.1049 - val_accuracy: 0.9670
# Epoch 16/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0493 - accuracy: 0.9812 - val_loss: 0.1053 - val_accuracy: 0.9670
# Epoch 17/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0537 - accuracy: 0.9824 - val_loss: 0.0946 - val_accuracy: 0.9648
# Epoch 18/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0408 - accuracy: 0.9849 - val_loss: 0.0866 - val_accuracy: 0.9693
# Epoch 19/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0438 - accuracy: 0.9835 - val_loss: 0.1220 - val_accuracy: 0.9625
# Epoch 20/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0386 - accuracy: 0.9858 - val_loss: 0.0906 - val_accuracy: 0.9739
# Epoch 21/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0392 - accuracy: 0.9869 - val_loss: 0.0874 - val_accuracy: 0.9614
# Epoch 22/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0419 - accuracy: 0.9849 - val_loss: 0.0984 - val_accuracy: 0.9625
# Epoch 23/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0275 - accuracy: 0.9903 - val_loss: 0.0685 - val_accuracy: 0.9784
# Epoch 24/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0511 - accuracy: 0.9821 - val_loss: 0.1508 - val_accuracy: 0.9591
# Epoch 25/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0543 - accuracy: 0.9835 - val_loss: 0.1490 - val_accuracy: 0.9534
# Epoch 26/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0465 - accuracy: 0.9827 - val_loss: 0.0927 - val_accuracy: 0.9659
# Epoch 27/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0295 - accuracy: 0.9898 - val_loss: 0.1167 - val_accuracy: 0.9557
# Epoch 28/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0272 - accuracy: 0.9912 - val_loss: 0.0783 - val_accuracy: 0.9727
# Epoch 29/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0279 - accuracy: 0.9909 - val_loss: 0.1052 - val_accuracy: 0.9693
# Epoch 30/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0393 - accuracy: 0.9858 - val_loss: 0.1058 - val_accuracy: 0.9739
# Epoch 31/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0284 - accuracy: 0.9903 - val_loss: 0.1119 - val_accuracy: 0.9682
# Epoch 32/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0430 - accuracy: 0.9866 - val_loss: 0.1551 - val_accuracy: 0.9682
# Epoch 33/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0372 - accuracy: 0.9861 - val_loss: 0.0774 - val_accuracy: 0.9727
# Epoch 34/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0308 - accuracy: 0.9883 - val_loss: 0.0646 - val_accuracy: 0.9795
# Epoch 35/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0279 - accuracy: 0.9898 - val_loss: 0.0726 - val_accuracy: 0.9807
# Epoch 36/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0319 - accuracy: 0.9918 - val_loss: 0.0829 - val_accuracy: 0.9761
# Epoch 37/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0378 - accuracy: 0.9898 - val_loss: 0.0545 - val_accuracy: 0.9875
# Epoch 38/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0271 - accuracy: 0.9923 - val_loss: 0.0647 - val_accuracy: 0.9830
# Epoch 39/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0326 - accuracy: 0.9872 - val_loss: 0.1235 - val_accuracy: 0.9682
# Epoch 40/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0327 - accuracy: 0.9906 - val_loss: 0.0663 - val_accuracy: 0.9830
# Epoch 41/100
# 110/110 [==============================] - 10s 91ms/step - loss: 0.0306 - accuracy: 0.9892 - val_loss: 0.0879 - val_accuracy: 0.9693
# Epoch 42/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0289 - accuracy: 0.9901 - val_loss: 0.0835 - val_accuracy: 0.9807
# Epoch 43/100
# 110/110 [==============================] - 10s 91ms/step - loss: 0.0296 - accuracy: 0.9906 - val_loss: 0.0921 - val_accuracy: 0.9830
# Epoch 44/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0209 - accuracy: 0.9920 - val_loss: 0.0773 - val_accuracy: 0.9818
# Epoch 45/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0423 - accuracy: 0.9855 - val_loss: 0.0960 - val_accuracy: 0.9614
# Epoch 46/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0293 - accuracy: 0.9912 - val_loss: 0.0900 - val_accuracy: 0.9739
# Epoch 47/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0233 - accuracy: 0.9932 - val_loss: 0.0659 - val_accuracy: 0.9795
# Epoch 48/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0246 - accuracy: 0.9920 - val_loss: 0.0628 - val_accuracy: 0.9795
# Epoch 49/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0242 - accuracy: 0.9935 - val_loss: 0.0536 - val_accuracy: 0.9830
# Epoch 50/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0261 - accuracy: 0.9912 - val_loss: 0.0654 - val_accuracy: 0.9784
# Epoch 51/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0100 - accuracy: 0.9963 - val_loss: 0.0868 - val_accuracy: 0.9739
# Epoch 52/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0145 - accuracy: 0.9963 - val_loss: 0.0606 - val_accuracy: 0.9761
# Epoch 53/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0192 - accuracy: 0.9940 - val_loss: 0.0533 - val_accuracy: 0.9807
# Epoch 54/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0218 - accuracy: 0.9929 - val_loss: 0.0644 - val_accuracy: 0.9807
# Epoch 55/100
# 110/110 [==============================] - 10s 93ms/step - loss: 0.0310 - accuracy: 0.9909 - val_loss: 0.0790 - val_accuracy: 0.9784
# Epoch 56/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0218 - accuracy: 0.9935 - val_loss: 0.0717 - val_accuracy: 0.9761
# Epoch 57/100
# 110/110 [==============================] - 10s 91ms/step - loss: 0.0165 - accuracy: 0.9960 - val_loss: 0.0474 - val_accuracy: 0.9807
# Epoch 58/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0221 - accuracy: 0.9926 - val_loss: 0.1052 - val_accuracy: 0.9693
# Epoch 59/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0189 - accuracy: 0.9929 - val_loss: 0.0578 - val_accuracy: 0.9795
# Epoch 60/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0268 - accuracy: 0.9901 - val_loss: 0.0698 - val_accuracy: 0.9750
# Epoch 61/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0212 - accuracy: 0.9935 - val_loss: 0.0894 - val_accuracy: 0.9727
# Epoch 62/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0224 - accuracy: 0.9926 - val_loss: 0.0960 - val_accuracy: 0.9727
# Epoch 63/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0329 - accuracy: 0.9886 - val_loss: 0.0484 - val_accuracy: 0.9864
# Epoch 64/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0327 - accuracy: 0.9901 - val_loss: 0.0615 - val_accuracy: 0.9852
# Epoch 65/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0118 - accuracy: 0.9969 - val_loss: 0.0810 - val_accuracy: 0.9784
# Epoch 66/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0233 - accuracy: 0.9926 - val_loss: 0.0578 - val_accuracy: 0.9818
# Epoch 67/100
# 110/110 [==============================] - 10s 93ms/step - loss: 0.0156 - accuracy: 0.9935 - val_loss: 0.0852 - val_accuracy: 0.9750
# Epoch 68/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0139 - accuracy: 0.9946 - val_loss: 0.0943 - val_accuracy: 0.9705
# Epoch 69/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0334 - accuracy: 0.9898 - val_loss: 0.0441 - val_accuracy: 0.9864
# Epoch 70/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0176 - accuracy: 0.9935 - val_loss: 0.0531 - val_accuracy: 0.9818
# Epoch 71/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.0621 - val_accuracy: 0.9875
# Epoch 72/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0192 - accuracy: 0.9929 - val_loss: 0.0572 - val_accuracy: 0.9841
# Epoch 73/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0158 - accuracy: 0.9940 - val_loss: 0.0812 - val_accuracy: 0.9784
# Epoch 74/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0176 - accuracy: 0.9937 - val_loss: 0.0791 - val_accuracy: 0.9750
# Epoch 75/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0228 - accuracy: 0.9929 - val_loss: 0.0717 - val_accuracy: 0.9727
# Epoch 76/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0115 - accuracy: 0.9963 - val_loss: 0.0357 - val_accuracy: 0.9830
# Epoch 77/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0172 - accuracy: 0.9943 - val_loss: 0.0472 - val_accuracy: 0.9841
# Epoch 78/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0165 - accuracy: 0.9955 - val_loss: 0.0250 - val_accuracy: 0.9886
# Epoch 79/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0123 - accuracy: 0.9966 - val_loss: 0.0303 - val_accuracy: 0.9875
# Epoch 80/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0166 - accuracy: 0.9940 - val_loss: 0.0412 - val_accuracy: 0.9852
# Epoch 81/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.0273 - val_accuracy: 0.9909
# Epoch 82/100
# 110/110 [==============================] - 10s 91ms/step - loss: 0.0087 - accuracy: 0.9974 - val_loss: 0.0504 - val_accuracy: 0.9773
# Epoch 83/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0208 - accuracy: 0.9949 - val_loss: 0.0634 - val_accuracy: 0.9818
# Epoch 84/100
# 110/110 [==============================] - 10s 91ms/step - loss: 0.0095 - accuracy: 0.9974 - val_loss: 0.0557 - val_accuracy: 0.9807
# Epoch 85/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0254 - accuracy: 0.9926 - val_loss: 0.1075 - val_accuracy: 0.9739
# Epoch 86/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0188 - accuracy: 0.9937 - val_loss: 0.0436 - val_accuracy: 0.9852
# Epoch 87/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.0596 - val_accuracy: 0.9830
# Epoch 88/100
# 110/110 [==============================] - 10s 91ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0641 - val_accuracy: 0.9852
# Epoch 89/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0119 - accuracy: 0.9952 - val_loss: 0.0521 - val_accuracy: 0.9852
# Epoch 90/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0140 - accuracy: 0.9940 - val_loss: 0.0684 - val_accuracy: 0.9807
# Epoch 91/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0145 - accuracy: 0.9963 - val_loss: 0.0549 - val_accuracy: 0.9830
# Epoch 92/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0113 - accuracy: 0.9963 - val_loss: 0.0487 - val_accuracy: 0.9852
# Epoch 93/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.0456 - val_accuracy: 0.9852
# Epoch 94/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0526 - val_accuracy: 0.9841
# Epoch 95/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0252 - accuracy: 0.9932 - val_loss: 0.0560 - val_accuracy: 0.9807
# Epoch 96/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0362 - val_accuracy: 0.9864
# Epoch 97/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0115 - accuracy: 0.9977 - val_loss: 0.0819 - val_accuracy: 0.9773
# Epoch 98/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 0.0594 - val_accuracy: 0.9852
# Epoch 99/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0162 - accuracy: 0.9940 - val_loss: 0.0639 - val_accuracy: 0.9830
# Epoch 100/100
# 110/110 [==============================] - 10s 92ms/step - loss: 0.0156 - accuracy: 0.9955 - val_loss: 0.0477 - val_accuracy: 0.9864
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0954 - accuracy: 0.9755
# Test_loss_value = 0.09538046270608902
# test_accuracy = 0.9755469560623169
# saving catalog...
#  catalog saved

# %% [markdown]
# PLOTTING RESULTS (Train vs Validation)

# %%
import matplotlib.pyplot as plt
def Train_Val_Plot(acc,val_acc,loss,val_loss):
    
    fig, (ax1, ax2) = plt.subplots(1,2, figsize= (15,10))
    fig.suptitle(" MODEL'S METRICS VISUALIZATION ")

    ax1.plot(range(1, len(acc) + 1), acc)
    ax1.plot(range(1, len(val_acc) + 1), val_acc)
    ax1.set_title('History of Accuracy')
    ax1.set_xlabel('Epochs')
    ax1.set_ylabel('Accuracy')
    ax1.legend(['training', 'validation'])
    
    ax2.plot(range(1, len(loss) + 1), loss)
    ax2.plot(range(1, len(val_loss) + 1), val_loss)
    ax2.set_title('History of Loss')
    ax2.set_xlabel('Epochs')
    ax2.set_ylabel('Loss')
    ax2.legend(['training', 'validation'])
    plt.show()
    

Train_Val_Plot(history.history['accuracy'],history.history['val_accuracy'],
               history.history['loss'],history.history['val_loss'])

# %%
y_pred=model.predict_classes(x_test)
y_pred_prb=model.predict_proba(x_test)

# %% [markdown]
# **Print_performance_metrics(y_test,y_pred):**
#
#         parameters:
#         y_test : actual label
#         y_pred_test : predicted labels
#
#         returns:
#         prints the accuracy, precision, recall, F1 score, ROC AUC score, Cohen Kappa Score, Matthews Corrcoef and classification report

# %%
target=["B","M"]
from sklearn import metrics
print('Accuracy:', np.round(metrics.accuracy_score(y_test, y_pred),4))
print('Precision:', np.round(metrics.precision_score(y_test, y_pred, average='weighted'),4))
print('Recall:', np.round(metrics.recall_score(y_test,y_pred, average='weighted'),4))
print('F1 Score:', np.round(metrics.f1_score(y_test, y_pred, average='weighted'),4))
print('ROC AUC Score:', np.round(metrics.roc_auc_score(y_test, y_pred_prb,multi_class='ovo', average='weighted'),4))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test, y_pred),4))
print('\t\tClassification Report:\n', metrics.classification_report(y_test, y_pred,target_names=target))
# Out:
# Accuracy: 0.9755
# Precision: 0.976
# Recall: 0.9755
# F1 Score: 0.9755
# ROC AUC Score: 0.9977
# Cohen Kappa Score: 0.9507
# 		Classification Report:
#                precision    recall  f1-score   support
#
#            B       0.96      0.99      0.98       417
#            M       0.99      0.96      0.97       360
#
#     accuracy                           0.98       777
#    macro avg       0.98      0.97      0.98       777
# weighted avg       0.98      0.98      0.98       777

# %%
len(x_train), len(x_test)
# Out:
# (4398, 777)

# %% [markdown]
# **Confusion Matrix:**

# %%
from sklearn.metrics import confusion_matrix
#Predict
y_prediction = model.predict_classes(x_test)
#Create confusion matrix and normalizes it over predicted (columns)
result = confusion_matrix(y_test, y_prediction , normalize='pred')
print(result * [[417],[360]])
# Out:
# [[401.48372093   3.60518732]
#  [ 13.39534884 356.88760807]]
